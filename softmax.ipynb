# %%
import numpy as np
import torch 
import torch.nn as nn 
import matplotlib.pyplot as plt

# %%
z=[1,2,3]
num=np.exp(z)
den=np.sum(np.exp(z))
sigma=num/den

print(sigma)
print(np.sum(sigma))
# Out:
# [0.09003057 0.24472847 0.66524096]
# 1.0

# %%
z=np.random.randint(-5,high=15,size=25)
print(z)
# Out:
# [-4  5  0  7 11 12  7  9  2  9 -4  0 -2 -1  0  1  4  9 10 10 -4 14 14 11
#   2]

# %%
softfun=nn.Softmax(dim=0)
sigmaT=softfun(torch.Tensor(z))
