# %%
import numpy as np
import torch 
import torch.nn as nn

# %%
x=[1,2,4,6,5,4,0]
n=len(x)

mean1=np.mean(x)
mean2=np.sum(x)/n 

print(mean1, mean2)
# Out:
# 3.142857142857143 3.142857142857143

# %%
var1=np.var(x,ddof=1)
print(var1)
# Out:
# 4.809523809523809
